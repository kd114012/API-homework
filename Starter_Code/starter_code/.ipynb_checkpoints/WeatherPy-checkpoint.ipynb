# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
temp_units = "imperial"
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output/weather_df.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []
# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 595

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")    


# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cayenne
# City not found. Skipping...
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | okha
# Processing Record 6 of Set 1 | aswan
# Processing Record 7 of Set 1 | padang
# City not found. Skipping...
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | pevek
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | whitianga
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | florin
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | lewistown
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | yerbogachen
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | tokmak
# Processing Record 23 of Set 1 | jinan
# Processing Record 24 of Set 1 | igarka
# Processing Record 25 of Set 1 | grindavik
# Processing Record 26 of Set 1 | sorland
# Processing Record 27 of Set 1 | tomatlan
# Processing Record 28 of Set 1 | samboan
# Processing Record 29 of Set 1 | tignere
# Processing Record 30 of Set 1 | can tho
# Processing Record 31 of Set 1 | aksarka
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | hofn
# Processing Record 34 of Set 1 | muroto
# Processing Record 35 of Set 1 | kuytun
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | murgab
# Processing Record 38 of Set 1 | santo amaro da imperatriz
# Processing Record 39 of Set 1 | lagoa
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | vardo
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | gamba
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | felanitx
# Processing Record 46 of Set 1 | hosakote
# Processing Record 47 of Set 1 | hambantota
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | novozybkov
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | hot springs
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | banda aceh
# Processing Record 5 of Set 2 | malm
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | gyanpur
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | vicosa
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | mayo
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | mount gambier
# City not found. Skipping...
# Processing Record 16 of Set 2 | goderich
# Processing Record 17 of Set 2 | sayyan
# Processing Record 18 of Set 2 | dom pedrito
# Processing Record 19 of Set 2 | kodiak
# City not found. Skipping...
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | oistins
# Processing Record 22 of Set 2 | sydney
# Processing Record 23 of Set 2 | cherskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | ulladulla
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | nome
# Processing Record 28 of Set 2 | schneeberg
# Processing Record 29 of Set 2 | san patricio
# Processing Record 30 of Set 2 | rio gallegos
# Processing Record 31 of Set 2 | westport
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | vao
# Processing Record 35 of Set 2 | sangar
# Processing Record 36 of Set 2 | pochutla
# City not found. Skipping...
# Processing Record 37 of Set 2 | champerico
# Processing Record 38 of Set 2 | kulynychi
# Processing Record 39 of Set 2 | ankazoabo
# Processing Record 40 of Set 2 | nouadhibou
# Processing Record 41 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 42 of Set 2 | kohlu
# Processing Record 43 of Set 2 | wilkie
# City not found. Skipping...
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | okhotsk
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | bandarbeyla
# Processing Record 48 of Set 2 | noumea
# Processing Record 49 of Set 2 | eureka
# Processing Record 1 of Set 3 | yar-sale
# Processing Record 2 of Set 3 | shellbrook
# Processing Record 3 of Set 3 | hastings
# Processing Record 4 of Set 3 | ati
# Processing Record 5 of Set 3 | hervey bay
# Processing Record 6 of Set 3 | flinders
# Processing Record 7 of Set 3 | jalu
# Processing Record 8 of Set 3 | coihaique
# Processing Record 9 of Set 3 | lavrentiya
# Processing Record 10 of Set 3 | tiksi
# Processing Record 11 of Set 3 | saint-joseph
# Processing Record 12 of Set 3 | mahmudabad
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | port-cartier
# City not found. Skipping...
# Processing Record 15 of Set 3 | palu
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | aden
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | les cayes
# Processing Record 20 of Set 3 | pouembout
# Processing Record 21 of Set 3 | antofagasta
# Processing Record 22 of Set 3 | chokurdakh
# Processing Record 23 of Set 3 | marawi
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | namibe
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | ixtapa
# Processing Record 28 of Set 3 | sembe
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | shubarshi
# Processing Record 31 of Set 3 | port elizabeth
# City not found. Skipping...
# Processing Record 32 of Set 3 | shingu
# Processing Record 33 of Set 3 | hobart
# Processing Record 34 of Set 3 | itoman
# Processing Record 35 of Set 3 | hithadhoo
# City not found. Skipping...
# Processing Record 36 of Set 3 | nabire
# Processing Record 37 of Set 3 | chapais
# Processing Record 38 of Set 3 | seydi
# Processing Record 39 of Set 3 | magistralnyy
# Processing Record 40 of Set 3 | ribeira grande
# Processing Record 41 of Set 3 | ust-tsilma
# City not found. Skipping...
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | sisimiut
# Processing Record 45 of Set 3 | northam
# Processing Record 46 of Set 3 | tarko-sale
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | vestmannaeyjar
# Processing Record 49 of Set 3 | nago
# Processing Record 1 of Set 4 | port lincoln
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | cape town
# City not found. Skipping...
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | coquimbo
# Processing Record 6 of Set 4 | grand gaube
# Processing Record 7 of Set 4 | robertsport
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | chicama
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 13 of Set 4 | yeppoon
# Processing Record 14 of Set 4 | shakhtinsk
# City not found. Skipping...
# Processing Record 15 of Set 4 | ambilobe
# Processing Record 16 of Set 4 | prince rupert
# Processing Record 17 of Set 4 | gogrial
# City not found. Skipping...
# Processing Record 18 of Set 4 | esso
# Processing Record 19 of Set 4 | qui nhon
# Processing Record 20 of Set 4 | arya
# Processing Record 21 of Set 4 | bilma
# Processing Record 22 of Set 4 | lipin bor
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | charters towers
# Processing Record 25 of Set 4 | athabasca
# Processing Record 26 of Set 4 | sao miguel do araguaia
# Processing Record 27 of Set 4 | kloulklubed
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | atar
# Processing Record 30 of Set 4 | kandi
# City not found. Skipping...
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | cabo san lucas
# Processing Record 33 of Set 4 | kupang
# Processing Record 34 of Set 4 | auki
# Processing Record 35 of Set 4 | tasiilaq
# Processing Record 36 of Set 4 | castro
# Processing Record 37 of Set 4 | alice springs
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | saint-pierre
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | djibo
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | manama
# Processing Record 44 of Set 4 | ostrovnoy
# City not found. Skipping...
# Processing Record 45 of Set 4 | pasni
# City not found. Skipping...
# Processing Record 46 of Set 4 | avera
# Processing Record 47 of Set 4 | novyy urengoy
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | krasnoarmeysk
# Processing Record 1 of Set 5 | ulaangom
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | arman
# City not found. Skipping...
# Processing Record 4 of Set 5 | richards bay
# Processing Record 5 of Set 5 | saldanha
# Processing Record 6 of Set 5 | bilibino
# Processing Record 7 of Set 5 | beloha
# Processing Record 8 of Set 5 | hokitika
# City not found. Skipping...
# Processing Record 9 of Set 5 | camalu
# Processing Record 10 of Set 5 | lorengau
# Processing Record 11 of Set 5 | asau
# Processing Record 12 of Set 5 | vanimo
# Processing Record 13 of Set 5 | nelson bay
# Processing Record 14 of Set 5 | mys shmidta
# Processing Record 15 of Set 5 | bubaque
# Processing Record 16 of Set 5 | zelenoborsk
# Processing Record 17 of Set 5 | noshiro
# Processing Record 18 of Set 5 | ocala
# Processing Record 19 of Set 5 | imbituba
# Processing Record 20 of Set 5 | sauda
# Processing Record 21 of Set 5 | posadas
# Processing Record 22 of Set 5 | qaanaaq
# Processing Record 23 of Set 5 | bonthe
# Processing Record 24 of Set 5 | leh
# City not found. Skipping...
# Processing Record 25 of Set 5 | fortuna
# Processing Record 26 of Set 5 | tuktoyaktuk
# Processing Record 27 of Set 5 | nicoya
# Processing Record 28 of Set 5 | ahipara
# Processing Record 29 of Set 5 | katsuura
# Processing Record 30 of Set 5 | dingle
# Processing Record 31 of Set 5 | nuevo progreso
# Processing Record 32 of Set 5 | diamantino
# Processing Record 33 of Set 5 | porto belo
# Processing Record 34 of Set 5 | rio grande
# Processing Record 35 of Set 5 | leningradskiy
# Processing Record 36 of Set 5 | hrinova
# Processing Record 37 of Set 5 | moree
# Processing Record 38 of Set 5 | tondano
# City not found. Skipping...
# Processing Record 39 of Set 5 | hay river
# City not found. Skipping...
# Processing Record 40 of Set 5 | codrington
# Processing Record 41 of Set 5 | pabrade
# Processing Record 42 of Set 5 | meadow lake
# Processing Record 43 of Set 5 | matagami
# Processing Record 44 of Set 5 | dosso
# City not found. Skipping...
# Processing Record 45 of Set 5 | beringovskiy
# Processing Record 46 of Set 5 | teya
# City not found. Skipping...
# Processing Record 47 of Set 5 | uromi
# Processing Record 48 of Set 5 | bay point
# Processing Record 49 of Set 5 | airai
# Processing Record 1 of Set 6 | yambio
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | kayes
# Processing Record 4 of Set 6 | waingapu
# Processing Record 5 of Set 6 | morehead
# Processing Record 6 of Set 6 | emborion
# Processing Record 7 of Set 6 | sistranda
# Processing Record 8 of Set 6 | santa marinella
# City not found. Skipping...
# Processing Record 9 of Set 6 | namatanai
# Processing Record 10 of Set 6 | kahului
# Processing Record 11 of Set 6 | wanning
# Processing Record 12 of Set 6 | chastyye
# Processing Record 13 of Set 6 | usatove
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | cooma
# Processing Record 16 of Set 6 | sokoni
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | evensk
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | lircay
# Processing Record 21 of Set 6 | nakamura
# Processing Record 22 of Set 6 | medina del campo
# Processing Record 23 of Set 6 | royan
# Processing Record 24 of Set 6 | camana
# Processing Record 25 of Set 6 | lima
# Processing Record 26 of Set 6 | esperance
# Processing Record 27 of Set 6 | bereda
# Processing Record 28 of Set 6 | catuday
# Processing Record 29 of Set 6 | asosa
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | roald
# City not found. Skipping...
# Processing Record 32 of Set 6 | pangody
# Processing Record 33 of Set 6 | amapa
# City not found. Skipping...
# Processing Record 34 of Set 6 | yarmouth
# Processing Record 35 of Set 6 | curillo
# Processing Record 36 of Set 6 | baj baj
# Processing Record 37 of Set 6 | vad
# Processing Record 38 of Set 6 | kalmunai
# Processing Record 39 of Set 6 | loralai
# Processing Record 40 of Set 6 | mantua
# Processing Record 41 of Set 6 | gat
# Processing Record 42 of Set 6 | waddan
# Processing Record 43 of Set 6 | maniitsoq
# Processing Record 44 of Set 6 | aykhal
# Processing Record 45 of Set 6 | camapua
# Processing Record 46 of Set 6 | mangan
# Processing Record 47 of Set 6 | dunedin
# Processing Record 48 of Set 6 | bethel
# Processing Record 49 of Set 6 | frolovo
# Processing Record 1 of Set 7 | meulaboh
# Processing Record 2 of Set 7 | san cristobal
# Processing Record 3 of Set 7 | ntcheu
# Processing Record 4 of Set 7 | skerries
# Processing Record 5 of Set 7 | bambanglipuro
# Processing Record 6 of Set 7 | lucapa
# Processing Record 7 of Set 7 | tete
# Processing Record 8 of Set 7 | honiara
# Processing Record 9 of Set 7 | sungaipenuh
# Processing Record 10 of Set 7 | santiago
# Processing Record 11 of Set 7 | hermiston
# Processing Record 12 of Set 7 | sola
# City not found. Skipping...
# Processing Record 13 of Set 7 | calvinia
# Processing Record 14 of Set 7 | husavik
# Processing Record 15 of Set 7 | lexington
# City not found. Skipping...
# Processing Record 16 of Set 7 | sorong
# Processing Record 17 of Set 7 | aleksandrovsk
# Processing Record 18 of Set 7 | molchanovo
# Processing Record 19 of Set 7 | fayaoue
# Processing Record 20 of Set 7 | havoysund
# Processing Record 21 of Set 7 | samokov
# Processing Record 22 of Set 7 | balabac
# Processing Record 23 of Set 7 | nyurba
# Processing Record 24 of Set 7 | senanga
# Processing Record 25 of Set 7 | hamadan
# Processing Record 26 of Set 7 | ekhabi
# Processing Record 27 of Set 7 | charleston
# Processing Record 28 of Set 7 | fairbanks
# Processing Record 29 of Set 7 | camacha
# Processing Record 30 of Set 7 | nioro
# Processing Record 31 of Set 7 | garowe
# Processing Record 32 of Set 7 | bischwiller
# Processing Record 33 of Set 7 | fonte boa
# Processing Record 34 of Set 7 | gilbues
# Processing Record 35 of Set 7 | ewa beach
# Processing Record 36 of Set 7 | mercedes
# Processing Record 37 of Set 7 | pirae
# Processing Record 38 of Set 7 | atambua
# Processing Record 39 of Set 7 | northport
# Processing Record 40 of Set 7 | osorno
# Processing Record 41 of Set 7 | aklavik
# Processing Record 42 of Set 7 | takoradi
# Processing Record 43 of Set 7 | marquette
# Processing Record 44 of Set 7 | aquiraz
# Processing Record 45 of Set 7 | abu kamal
# City not found. Skipping...
# Processing Record 46 of Set 7 | blagoyevo
# Processing Record 47 of Set 7 | luderitz
# Processing Record 48 of Set 7 | maarianhamina
# Processing Record 49 of Set 7 | zhezkazgan
# Processing Record 1 of Set 8 | njombe
# Processing Record 2 of Set 8 | shirokiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | beruwala
# Processing Record 4 of Set 8 | lata
# Processing Record 5 of Set 8 | palmer
# Processing Record 6 of Set 8 | ratnagiri
# Processing Record 7 of Set 8 | broome
# Processing Record 8 of Set 8 | del rio
# Processing Record 9 of Set 8 | san juan
# Processing Record 10 of Set 8 | camocim
# Processing Record 11 of Set 8 | san luis
# Processing Record 12 of Set 8 | vattalkundu
# Processing Record 13 of Set 8 | bahia de caraquez
# Processing Record 14 of Set 8 | pisco
# Processing Record 15 of Set 8 | narsaq
# Processing Record 16 of Set 8 | rayong
# Processing Record 17 of Set 8 | riyadh
# City not found. Skipping...
# Processing Record 18 of Set 8 | poronaysk
# Processing Record 19 of Set 8 | tougan
# Processing Record 20 of Set 8 | tahta
# Processing Record 21 of Set 8 | ndele
# Processing Record 22 of Set 8 | victor harbor
# Processing Record 23 of Set 8 | sinjar
# Processing Record 24 of Set 8 | fort saint james
# Processing Record 25 of Set 8 | kushmurun
# Processing Record 26 of Set 8 | grand-santi
# Processing Record 27 of Set 8 | constitucion
# City not found. Skipping...
# Processing Record 28 of Set 8 | chuy
# Processing Record 29 of Set 8 | desur
# City not found. Skipping...
# Processing Record 30 of Set 8 | baghdad
# Processing Record 31 of Set 8 | tessalit
# Processing Record 32 of Set 8 | brae
# City not found. Skipping...
# Processing Record 33 of Set 8 | port hardy
# City not found. Skipping...
# Processing Record 34 of Set 8 | moyale
# City not found. Skipping...
# Processing Record 35 of Set 8 | glendive
# Processing Record 36 of Set 8 | brokopondo
# Processing Record 37 of Set 8 | mount isa
# Processing Record 38 of Set 8 | mogadishu
# Processing Record 39 of Set 8 | manacapuru
# Processing Record 40 of Set 8 | vieux-habitants
# Processing Record 41 of Set 8 | shubarkuduk
# Processing Record 42 of Set 8 | kamaishi
# Processing Record 43 of Set 8 | sao filipe
# Processing Record 44 of Set 8 | macheng
# Processing Record 45 of Set 8 | kalmar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 8 | mazyr
# Processing Record 47 of Set 8 | kama
# Processing Record 48 of Set 8 | tautira
# Processing Record 49 of Set 8 | yulara
# Processing Record 1 of Set 9 | tarrafal
# Processing Record 2 of Set 9 | waitati
# Processing Record 3 of Set 9 | anchorage
# Processing Record 4 of Set 9 | riachao das neves
# Processing Record 5 of Set 9 | burnie
# Processing Record 6 of Set 9 | novo aripuana
# Processing Record 7 of Set 9 | yuzhno-kurilsk
# Processing Record 8 of Set 9 | hovd
# Processing Record 9 of Set 9 | iqaluit
# Processing Record 10 of Set 9 | livny
# Processing Record 11 of Set 9 | kondinskoye
# Processing Record 12 of Set 9 | male
# Processing Record 13 of Set 9 | chiredzi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 9 | karlskrona
# Processing Record 15 of Set 9 | isangel
# Processing Record 16 of Set 9 | mahibadhoo
# Processing Record 17 of Set 9 | nacala
# Processing Record 18 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 9 | clyde
# Processing Record 20 of Set 9 | khakurinokhabl
# Processing Record 21 of Set 9 | mormugao
# Processing Record 22 of Set 9 | papayal
# Processing Record 23 of Set 9 | bintulu
# Processing Record 24 of Set 9 | polis
# Processing Record 25 of Set 9 | masuguru
# Processing Record 26 of Set 9 | gorontalo
# Processing Record 27 of Set 9 | vrangel
# Processing Record 28 of Set 9 | moses lake
# Processing Record 29 of Set 9 | wangkui
# Processing Record 30 of Set 9 | kerman
# Processing Record 31 of Set 9 | saint-augustin
# Processing Record 32 of Set 9 | stornoway
# Processing Record 33 of Set 9 | hami
# Processing Record 34 of Set 9 | manaus
# Processing Record 35 of Set 9 | yaan
# Processing Record 36 of Set 9 | grand river south east
# Processing Record 37 of Set 9 | can
# Processing Record 38 of Set 9 | xingyi
# Processing Record 39 of Set 9 | mutis
# Processing Record 40 of Set 9 | manono
# Processing Record 41 of Set 9 | lazaro cardenas
# Processing Record 42 of Set 9 | dukat
# Processing Record 43 of Set 9 | bacalar
# Processing Record 44 of Set 9 | andenes
# Processing Record 45 of Set 9 | buala
# Processing Record 46 of Set 9 | peniche
# Processing Record 47 of Set 9 | laguna
# Processing Record 48 of Set 9 | olafsvik
# Processing Record 49 of Set 9 | gerede
# Processing Record 1 of Set 10 | monze
# Processing Record 2 of Set 10 | mazagao
# Processing Record 3 of Set 10 | elizabeth city
# Processing Record 4 of Set 10 | strezhevoy
# Processing Record 5 of Set 10 | kavieng
# Processing Record 6 of Set 10 | san buenaventura
# Processing Record 7 of Set 10 | port-gentil
# Processing Record 8 of Set 10 | alice town
# Processing Record 9 of Set 10 | paamiut
# City not found. Skipping...
# Processing Record 10 of Set 10 | montepuez
# Processing Record 11 of Set 10 | chitral
# Processing Record 12 of Set 10 | luganville
# Processing Record 13 of Set 10 | svetlaya
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | debre birhan
# Processing Record 16 of Set 10 | hualmay
# Processing Record 17 of Set 10 | saint-leu
# Processing Record 18 of Set 10 | monte patria
# Processing Record 19 of Set 10 | riverton
# City not found. Skipping...
# Processing Record 20 of Set 10 | gayny
# Processing Record 21 of Set 10 | tambun
# Processing Record 22 of Set 10 | chifeng
# Processing Record 23 of Set 10 | kimbe
# Processing Record 24 of Set 10 | elat
# Processing Record 25 of Set 10 | minjur
# Processing Record 26 of Set 10 | krasnoselkup
# Processing Record 27 of Set 10 | carutapera
# Processing Record 28 of Set 10 | vila
# Processing Record 29 of Set 10 | haines junction
# Processing Record 30 of Set 10 | wuchi
# City not found. Skipping...
# Processing Record 31 of Set 10 | vierzon
# Processing Record 32 of Set 10 | alofi
# Processing Record 33 of Set 10 | manyana
# City not found. Skipping...
# Processing Record 34 of Set 10 | acoua
# City not found. Skipping...
# Processing Record 35 of Set 10 | zhigansk
# Processing Record 36 of Set 10 | tual
# Processing Record 37 of Set 10 | masyaf
# Processing Record 38 of Set 10 | vostok
# Processing Record 39 of Set 10 | karratha
# Processing Record 40 of Set 10 | cabedelo
# Processing Record 41 of Set 10 | akdepe
# Processing Record 42 of Set 10 | phan rang
# Processing Record 43 of Set 10 | udachnyy
# City not found. Skipping...
# Processing Record 44 of Set 10 | union
# City not found. Skipping...
# Processing Record 45 of Set 10 | samarai
# Processing Record 46 of Set 10 | inta
# City not found. Skipping...
# Processing Record 47 of Set 10 | collie
# Processing Record 48 of Set 10 | mau
# Processing Record 49 of Set 10 | govindgarh
# Processing Record 1 of Set 11 | san javier
# Processing Record 2 of Set 11 | aksu
# Processing Record 3 of Set 11 | ilhabela
# Processing Record 4 of Set 11 | erenhot
# Processing Record 5 of Set 11 | jian
# Processing Record 6 of Set 11 | jumla
# Processing Record 7 of Set 11 | khandbari
# Processing Record 8 of Set 11 | puerto maldonado
# City not found. Skipping...
# Processing Record 9 of Set 11 | itarema
# City not found. Skipping...
# Processing Record 10 of Set 11 | ketchikan
# Processing Record 11 of Set 11 | okoneshnikovo
# Processing Record 12 of Set 11 | sandwick
# Processing Record 13 of Set 11 | inhambane
# Processing Record 14 of Set 11 | sao felix do xingu
# Processing Record 15 of Set 11 | kokopo
# Processing Record 16 of Set 11 | katherine
# Processing Record 17 of Set 11 | puerto del rosario
# Processing Record 18 of Set 11 | ocos
# Processing Record 19 of Set 11 | kardamaina
# Processing Record 20 of Set 11 | bengkulu
# Processing Record 21 of Set 11 | wagar
# Processing Record 22 of Set 11 | pyapon
# Processing Record 23 of Set 11 | pijao
# Processing Record 24 of Set 11 | wang noi
# Processing Record 25 of Set 11 | comodoro rivadavia
# Processing Record 26 of Set 11 | mandera
# Processing Record 27 of Set 11 | komsomolets
# City not found. Skipping...
# Processing Record 28 of Set 11 | vila franca do campo
# Processing Record 29 of Set 11 | aitape
# Processing Record 30 of Set 11 | killybegs
# Processing Record 31 of Set 11 | bundaberg
# Processing Record 32 of Set 11 | rosia de secas
# Processing Record 33 of Set 11 | abha
# Processing Record 34 of Set 11 | portland
# Processing Record 35 of Set 11 | houma
# Processing Record 36 of Set 11 | turukhansk
# Processing Record 37 of Set 11 | adrar
# Processing Record 38 of Set 11 | mastic beach
# Processing Record 39 of Set 11 | culiacancito
# Processing Record 40 of Set 11 | moron
# Processing Record 41 of Set 11 | mandan
# Processing Record 42 of Set 11 | muzhi
# Processing Record 43 of Set 11 | becerril
# Processing Record 44 of Set 11 | piacabucu
# Processing Record 45 of Set 11 | kembe
# Processing Record 46 of Set 11 | kyra
# Processing Record 47 of Set 11 | jiangkou
# ------------------------------
# Data Retrieval Complete
# ------------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}


    
# establish dataframe
weather_dataframe = pd.DataFrame(weather_dict)
# show the top of the dataframe
weather_dataframe.head()
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 0         cayenne         100      GF  1670276968        89   4.9333
# 1  severo-kurilsk          98      RU  1670276902        76  50.6789
# 2       jamestown           0      US  1670276969        26  42.0970
# 3       saskylakh         100      RU  1670276969        89  71.9167
# 4            okha          65      RU  1670276970        90  53.5739
#
#         Lng  Max Temp  Wind Speed
# 0  -52.3333     78.84        3.44
# 1  156.1250     23.65       21.18
# 2  -79.2353     46.04       10.36
# 3  114.0833    -11.97       19.73
# 4  142.9478      0.50       13.85

# %%
# Export the City_Data into a csv
weather_dataframe.to_csv("../output_data/cities.csv", index_label="City_ID")
weather_dataframe = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
weather_dataframe.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity      Lat  \
# City_ID
# 0               cayenne         100      GF  1670276968        89   4.9333
# 1        severo-kurilsk          98      RU  1670276902        76  50.6789
# 2             jamestown           0      US  1670276969        26  42.0970
# 3             saskylakh         100      RU  1670276969        89  71.9167
# 4                  okha          65      RU  1670276970        90  53.5739
#
#               Lng  Max Temp  Wind Speed
# City_ID
# 0        -52.3333     78.84        3.44
# 1        156.1250     23.65       21.18
# 2        -79.2353     46.04       10.36
# 3        114.0833    -11.97       19.73
# 4        142.9478      0.50       13.85

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Temperature (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Humidity (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
weather_data_north = weather_dataframe[weather_dataframe['Lat'] >= 0]

weather_data_south = weather_dataframe[weather_dataframe['Lat'] < 0]

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temperature (F)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(1, 1), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(min(weather_dataframe['Max Temp'])-10, max(weather_dataframe['Max Temp'])+10)

# Set the limits of the x axis:
plt.xlim(-3, max(weather_dataframe['Lat'])+3)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. MaxTemp_North.png')

# Show plot:
plt.show()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq2 = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temp', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq2,(-25,43),fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(30, 100)

# Set the limits of the x axis:
plt.xlim(min(weather_dataframe['Lat'])-3, +1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. MaxTemp_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude', fontsize=20)
plt.ylabel('Humidity (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(51,6),fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-6, 110)

# Set the limits of the x axis:
plt.xlim(-4, 82)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Humidity_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude', fontsize=20)
plt.ylabel('Humidity (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-55,22), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(10, 110)

# Set the limits of the x axis:
plt.xlim(-57, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Humidity_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(35,25), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-8, 110)

# Set the limits of the x axis:
plt.xlim(-3, 82)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Cloudiness_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-56,8), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-7, 108)

# Set the limits of the x axis:
plt.xlim(-58, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Cloudiness_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Wind Speed']

# Perform a linear regression for wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed (mph)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(2,42), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-3, 48)

# Set the limits of the x axis:
plt.xlim(-3, 82)


# Save the figure:
plt.savefig('../output_data/City Latitude vs. Wind_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Wind Speed']

# Perform a linear regression on wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed (mph)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-19.5,21), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-1, 25)

# Set the limits of the x axis:
plt.xlim(-58, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Wind_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
