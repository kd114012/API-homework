# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
temp_units = "imperial"
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output CSV
output_data_file = "Output/weather_df.csv"

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []
# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | pussi
# Processing Record 2 of Set 1 | waipawa
# Processing Record 3 of Set 1 | tampakan
# Processing Record 4 of Set 1 | aklavik
# Processing Record 5 of Set 1 | thompson
# City not found. Skipping...
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | grand river south east
# Processing Record 8 of Set 1 | kruisfontein
# Processing Record 9 of Set 1 | tual
# Processing Record 10 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | butaritari
# City not found. Skipping...
# Processing Record 14 of Set 1 | vallenar
# Processing Record 15 of Set 1 | katsuura
# Processing Record 16 of Set 1 | lodja
# Processing Record 17 of Set 1 | victoria
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | impfondo
# Processing Record 20 of Set 1 | ferrol
# City not found. Skipping...
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | hualmay
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | shiyan
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | ratnagiri
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | beian
# City not found. Skipping...
# Processing Record 32 of Set 1 | ixtapa
# Processing Record 33 of Set 1 | geraldton
# Processing Record 34 of Set 1 | waingapu
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | kahului
# Processing Record 43 of Set 1 | fort abbas
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | dawlatabad
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | kerouane
# Processing Record 48 of Set 1 | adrar
# Processing Record 49 of Set 1 | felanitx
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | samarai
# Processing Record 4 of Set 2 | russell
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | kirakira
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | dingle
# Processing Record 11 of Set 2 | ketchikan
# Processing Record 12 of Set 2 | mys shmidta
# Processing Record 13 of Set 2 | sechura
# Processing Record 14 of Set 2 | santa rosa
# Processing Record 15 of Set 2 | isangel
# Processing Record 16 of Set 2 | portland
# Processing Record 17 of Set 2 | katherine
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | dikson
# City not found. Skipping...
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | phalodi
# Processing Record 23 of Set 2 | libreville
# Processing Record 24 of Set 2 | plettenberg bay
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | cockburn town
# Processing Record 27 of Set 2 | labuhan
# Processing Record 28 of Set 2 | makakilo city
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | fort-shevchenko
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | atasu
# Processing Record 34 of Set 2 | hilo
# City not found. Skipping...
# Processing Record 35 of Set 2 | joshimath
# Processing Record 36 of Set 2 | kedrovyy
# Processing Record 37 of Set 2 | hambantota
# Processing Record 38 of Set 2 | north platte
# Processing Record 39 of Set 2 | xiaolan
# Processing Record 40 of Set 2 | tabas
# Processing Record 41 of Set 2 | vieques
# Processing Record 42 of Set 2 | gardez
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | trincomalee
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | pacific grove
# Processing Record 47 of Set 2 | airai
# Processing Record 48 of Set 2 | floresta
# Processing Record 49 of Set 2 | idritsa
# City not found. Skipping...
# Processing Record 1 of Set 3 | maragogi
# Processing Record 2 of Set 3 | atar
# Processing Record 3 of Set 3 | tiksi
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | mandalgovi
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | nioro
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | baruun-urt
# Processing Record 11 of Set 3 | oksovskiy
# Processing Record 12 of Set 3 | mukhen
# Processing Record 13 of Set 3 | paamiut
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | aasiaat
# Processing Record 16 of Set 3 | nemuro
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | verkhoyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | narsaq
# Processing Record 20 of Set 3 | ust-maya
# Processing Record 21 of Set 3 | mazarron
# Processing Record 22 of Set 3 | namibe
# Processing Record 23 of Set 3 | hearst
# Processing Record 24 of Set 3 | mkushi
# Processing Record 25 of Set 3 | xichang
# City not found. Skipping...
# Processing Record 26 of Set 3 | port macquarie
# Processing Record 27 of Set 3 | isla vista
# Processing Record 28 of Set 3 | koutsouras
# Processing Record 29 of Set 3 | yei
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | san policarpo
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | mandalgarh
# Processing Record 35 of Set 3 | flinders
# Processing Record 36 of Set 3 | coquimbo
# Processing Record 37 of Set 3 | saldanha
# City not found. Skipping...
# Processing Record 38 of Set 3 | merin
# Processing Record 39 of Set 3 | constitucion
# Processing Record 40 of Set 3 | sao joao da barra
# Processing Record 41 of Set 3 | rio brilhante
# Processing Record 42 of Set 3 | san ramon
# Processing Record 43 of Set 3 | mantenopolis
# Processing Record 44 of Set 3 | ginda
# Processing Record 45 of Set 3 | puerto ayacucho
# Processing Record 46 of Set 3 | lincoln
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | mau
# Processing Record 1 of Set 4 | grand gaube
# Processing Record 2 of Set 4 | bengkulu
# Processing Record 3 of Set 4 | shu
# Processing Record 4 of Set 4 | aykhal
# Processing Record 5 of Set 4 | faanui
# Processing Record 6 of Set 4 | muros
# City not found. Skipping...
# Processing Record 7 of Set 4 | lumberton
# City not found. Skipping...
# Processing Record 8 of Set 4 | arlit
# City not found. Skipping...
# Processing Record 9 of Set 4 | laguna
# Processing Record 10 of Set 4 | deputatskiy
# Processing Record 11 of Set 4 | puerto el triunfo
# Processing Record 12 of Set 4 | anadyr
# Processing Record 13 of Set 4 | boundiali
# Processing Record 14 of Set 4 | chuy
# Processing Record 15 of Set 4 | huainan
# Processing Record 16 of Set 4 | willowmore
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | port lincoln
# Processing Record 19 of Set 4 | sitka
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | carnarvon
# City not found. Skipping...
# Processing Record 22 of Set 4 | meulaboh
# Processing Record 23 of Set 4 | wattegama
# Processing Record 24 of Set 4 | harer
# Processing Record 25 of Set 4 | pedasi
# Processing Record 26 of Set 4 | upernavik
# Processing Record 27 of Set 4 | san quintin
# Processing Record 28 of Set 4 | morant bay
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | santa cruz de tenerife
# Processing Record 31 of Set 4 | ludvika
# Processing Record 32 of Set 4 | svetlyy
# Processing Record 33 of Set 4 | fairbanks
# Processing Record 34 of Set 4 | glyadyanskoye
# Processing Record 35 of Set 4 | mgachi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 4 | jiuquan
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | campos altos
# Processing Record 39 of Set 4 | rocha
# Processing Record 40 of Set 4 | egvekinot
# Processing Record 41 of Set 4 | natal
# Processing Record 42 of Set 4 | san cristobal
# Processing Record 43 of Set 4 | ishigaki
# Processing Record 44 of Set 4 | penzance
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | omsukchan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 4 | wanxian
# Processing Record 48 of Set 4 | kodiak
# Processing Record 49 of Set 4 | barrow
# Processing Record 1 of Set 5 | prieska
# Processing Record 2 of Set 5 | puerto escondido
# Processing Record 3 of Set 5 | rio branco
# Processing Record 4 of Set 5 | miri
# Processing Record 5 of Set 5 | lavrentiya
# Processing Record 6 of Set 5 | chapais
# Processing Record 7 of Set 5 | labuan
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | chifeng
# Processing Record 10 of Set 5 | ust-ilimsk
# Processing Record 11 of Set 5 | rockport
# Processing Record 12 of Set 5 | batagay
# Processing Record 13 of Set 5 | bukama
# Processing Record 14 of Set 5 | panama city
# Processing Record 15 of Set 5 | bereda
# Processing Record 16 of Set 5 | bandarbeyla
# Processing Record 17 of Set 5 | ostrovnoy
# Processing Record 18 of Set 5 | nueva loja
# Processing Record 19 of Set 5 | solton
# Processing Record 20 of Set 5 | batsfjord
# Processing Record 21 of Set 5 | trofors
# Processing Record 22 of Set 5 | tambo
# Processing Record 23 of Set 5 | baykit
# City not found. Skipping...
# Processing Record 24 of Set 5 | belaya gora
# Processing Record 25 of Set 5 | batagay-alyta
# Processing Record 26 of Set 5 | urucara
# Processing Record 27 of Set 5 | norden
# Processing Record 28 of Set 5 | pontianak
# Processing Record 29 of Set 5 | bayir
# Processing Record 30 of Set 5 | neiafu
# City not found. Skipping...
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | yulara
# Processing Record 33 of Set 5 | ambulu
# Processing Record 34 of Set 5 | waldoboro
# Processing Record 35 of Set 5 | roma
# Processing Record 36 of Set 5 | gloria do goita
# Processing Record 37 of Set 5 | akcakoca
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | lieksa
# Processing Record 40 of Set 5 | zonguldak
# Processing Record 41 of Set 5 | albi
# Processing Record 42 of Set 5 | biak
# Processing Record 43 of Set 5 | saint-louis
# City not found. Skipping...
# Processing Record 44 of Set 5 | boende
# Processing Record 45 of Set 5 | santa cruz
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | severo-yeniseyskiy
# Processing Record 48 of Set 5 | yuanping
# Processing Record 49 of Set 5 | kloulklubed
# Processing Record 1 of Set 6 | cherskiy
# Processing Record 2 of Set 6 | sao felix do xingu
# Processing Record 3 of Set 6 | broome
# Processing Record 4 of Set 6 | nome
# Processing Record 5 of Set 6 | cidreira
# Processing Record 6 of Set 6 | camana
# Processing Record 7 of Set 6 | tchollire
# Processing Record 8 of Set 6 | diamantino
# Processing Record 9 of Set 6 | tura
# Processing Record 10 of Set 6 | mmabatho
# Processing Record 11 of Set 6 | erzin
# Processing Record 12 of Set 6 | tasiilaq
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | lebork
# Processing Record 15 of Set 6 | ishim
# City not found. Skipping...
# Processing Record 16 of Set 6 | cap malheureux
# Processing Record 17 of Set 6 | gwadar
# Processing Record 18 of Set 6 | maldonado
# Processing Record 19 of Set 6 | cuervos
# Processing Record 20 of Set 6 | ucluelet
# City not found. Skipping...
# Processing Record 21 of Set 6 | palmer
# Processing Record 22 of Set 6 | potenza
# Processing Record 23 of Set 6 | goalpara
# Processing Record 24 of Set 6 | herat
# Processing Record 25 of Set 6 | nanortalik
# Processing Record 26 of Set 6 | flora
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | tuxpan
# Processing Record 29 of Set 6 | tuban
# Processing Record 30 of Set 6 | shorapani
# Processing Record 31 of Set 6 | bambous virieux
# Processing Record 32 of Set 6 | charters towers
# Processing Record 33 of Set 6 | nouadhibou
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | nadym
# Processing Record 36 of Set 6 | media luna
# Processing Record 37 of Set 6 | kampen
# Processing Record 38 of Set 6 | launceston
# Processing Record 39 of Set 6 | marysville
# Processing Record 40 of Set 6 | sungai besar
# Processing Record 41 of Set 6 | goderich
# Processing Record 42 of Set 6 | kaeo
# Processing Record 43 of Set 6 | smithers
# Processing Record 44 of Set 6 | riverton
# Processing Record 45 of Set 6 | labrea
# Processing Record 46 of Set 6 | souillac
# City not found. Skipping...
# Processing Record 47 of Set 6 | karimganj
# Processing Record 48 of Set 6 | caravelas
# City not found. Skipping...
# Processing Record 49 of Set 6 | alyangula
# City not found. Skipping...
# Processing Record 1 of Set 7 | praia
# Processing Record 2 of Set 7 | srednekolymsk
# City not found. Skipping...
# Processing Record 3 of Set 7 | dunedin
# Processing Record 4 of Set 7 | kyra
# Processing Record 5 of Set 7 | trindade
# Processing Record 6 of Set 7 | harper
# Processing Record 7 of Set 7 | ust-kuyga
# Processing Record 8 of Set 7 | osorno
# Processing Record 9 of Set 7 | micheweni
# Processing Record 10 of Set 7 | beringovskiy
# Processing Record 11 of Set 7 | tarpon springs
# City not found. Skipping...
# Processing Record 12 of Set 7 | stephenville
# Processing Record 13 of Set 7 | iqaluit
# Processing Record 14 of Set 7 | yar-sale
# Processing Record 15 of Set 7 | denpasar
# Processing Record 16 of Set 7 | san francisco
# Processing Record 17 of Set 7 | qujing
# Processing Record 18 of Set 7 | morondava
# City not found. Skipping...
# Processing Record 19 of Set 7 | hithadhoo
# Processing Record 20 of Set 7 | quchan
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | houston
# Processing Record 23 of Set 7 | elizabeth city
# Processing Record 24 of Set 7 | najran
# Processing Record 25 of Set 7 | mmathubudukwane
# Processing Record 26 of Set 7 | tuatapere
# Processing Record 27 of Set 7 | coro
# Processing Record 28 of Set 7 | marovoay
# City not found. Skipping...
# Processing Record 29 of Set 7 | anzoategui
# Processing Record 30 of Set 7 | lazaro cardenas
# Processing Record 31 of Set 7 | guayaramerin
# Processing Record 32 of Set 7 | camapua
# Processing Record 33 of Set 7 | brandon
# Processing Record 34 of Set 7 | olinda
# Processing Record 35 of Set 7 | dosso
# Processing Record 36 of Set 7 | zhizdra
# Processing Record 37 of Set 7 | avera
# Processing Record 38 of Set 7 | buala
# Processing Record 39 of Set 7 | cayenne
# Processing Record 40 of Set 7 | mokolo
# Processing Record 41 of Set 7 | usinsk
# Processing Record 42 of Set 7 | eureka
# Processing Record 43 of Set 7 | menongue
# Processing Record 44 of Set 7 | vardo
# Processing Record 45 of Set 7 | huntsville
# Processing Record 46 of Set 7 | methoni
# Processing Record 47 of Set 7 | krasnoselkup
# Processing Record 48 of Set 7 | inhambane
# Processing Record 49 of Set 7 | xuddur
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 8 | omboue
# Processing Record 2 of Set 8 | pangkalanbuun
# Processing Record 3 of Set 8 | nhulunbuy
# Processing Record 4 of Set 8 | pryazha
# Processing Record 5 of Set 8 | concepcion
# Processing Record 6 of Set 8 | chumphon
# Processing Record 7 of Set 8 | wanaka
# City not found. Skipping...
# Processing Record 8 of Set 8 | grindavik
# Processing Record 9 of Set 8 | pisco
# Processing Record 10 of Set 8 | warrington
# Processing Record 11 of Set 8 | yantal
# Processing Record 12 of Set 8 | siocon
# Processing Record 13 of Set 8 | soma
# Processing Record 14 of Set 8 | jinxiang
# Processing Record 15 of Set 8 | ayan
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | bobrovytsya
# Processing Record 18 of Set 8 | puerto colombia
# City not found. Skipping...
# Processing Record 19 of Set 8 | olafsvik
# Processing Record 20 of Set 8 | warmbad
# Processing Record 21 of Set 8 | lubango
# Processing Record 22 of Set 8 | ammon
# Processing Record 23 of Set 8 | sal rei
# Processing Record 24 of Set 8 | asau
# Processing Record 25 of Set 8 | irugur
# Processing Record 26 of Set 8 | djougou
# Processing Record 27 of Set 8 | jacareacanga
# Processing Record 28 of Set 8 | primorsk
# Processing Record 29 of Set 8 | contai
# Processing Record 30 of Set 8 | lesnoye
# Processing Record 31 of Set 8 | ilebo
# Processing Record 32 of Set 8 | riyadh
# Processing Record 33 of Set 8 | faya
# Processing Record 34 of Set 8 | tazmalt
# Processing Record 35 of Set 8 | chancay
# Processing Record 36 of Set 8 | gyanpur
# Processing Record 37 of Set 8 | jalu
# Processing Record 38 of Set 8 | lorengau
# Processing Record 39 of Set 8 | onega
# Processing Record 40 of Set 8 | matagami
# Processing Record 41 of Set 8 | piacabucu
# Processing Record 42 of Set 8 | huarmey
# Processing Record 43 of Set 8 | muroto
# City not found. Skipping...
# Processing Record 44 of Set 8 | ninotsminda
# Processing Record 45 of Set 8 | gejiu
# City not found. Skipping...
# Processing Record 46 of Set 8 | santa maria
# Processing Record 47 of Set 8 | bilma
# Processing Record 48 of Set 8 | stromness
# Processing Record 49 of Set 8 | silao
# Processing Record 1 of Set 9 | san rafael
# Processing Record 2 of Set 9 | missoula
# Processing Record 3 of Set 9 | codrington
# Processing Record 4 of Set 9 | yerbogachen
# Processing Record 5 of Set 9 | margate
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 9 | mahanoro
# Processing Record 7 of Set 9 | buckeye
# Processing Record 8 of Set 9 | dengzhou
# Processing Record 9 of Set 9 | jinchang
# Processing Record 10 of Set 9 | guerrero negro
# Processing Record 11 of Set 9 | goure
# City not found. Skipping...
# Processing Record 12 of Set 9 | hay river
# Processing Record 13 of Set 9 | insar
# Processing Record 14 of Set 9 | nanzhang
# Processing Record 15 of Set 9 | port hardy
# Processing Record 16 of Set 9 | longyearbyen
# Processing Record 17 of Set 9 | abilene
# Processing Record 18 of Set 9 | mackay
# Processing Record 19 of Set 9 | phan rang
# Processing Record 20 of Set 9 | talnakh
# Processing Record 21 of Set 9 | ambon
# Processing Record 22 of Set 9 | nanuque
# Processing Record 23 of Set 9 | yangshe
# Processing Record 24 of Set 9 | araouane
# Processing Record 25 of Set 9 | kristiansund
# Processing Record 26 of Set 9 | yarmouth
# Processing Record 27 of Set 9 | pontivy
# Processing Record 28 of Set 9 | ariquemes
# Processing Record 29 of Set 9 | barra do garcas
# City not found. Skipping...
# Processing Record 30 of Set 9 | valmiera
# Processing Record 31 of Set 9 | san vicente
# Processing Record 32 of Set 9 | sinnamary
# Processing Record 33 of Set 9 | sovetskoye
# Processing Record 34 of Set 9 | sao jose da coroa grande
# Processing Record 35 of Set 9 | camacari
# Processing Record 36 of Set 9 | galesong
# Processing Record 37 of Set 9 | tigil
# Processing Record 38 of Set 9 | acapulco
# Processing Record 39 of Set 9 | misratah
# Processing Record 40 of Set 9 | krasnoshchekovo
# Processing Record 41 of Set 9 | along
# Processing Record 42 of Set 9 | gari
# Processing Record 43 of Set 9 | talaya
# Processing Record 44 of Set 9 | ust-nera
# Processing Record 45 of Set 9 | kermanshah
# Processing Record 46 of Set 9 | pocos de caldas
# Processing Record 47 of Set 9 | north bend
# Processing Record 48 of Set 9 | coahuayana
# Processing Record 49 of Set 9 | hamamatsu
# Processing Record 1 of Set 10 | viru
# Processing Record 2 of Set 10 | khandyga
# Processing Record 3 of Set 10 | fortuna
# Processing Record 4 of Set 10 | uyemskiy
# Processing Record 5 of Set 10 | nichinan
# Processing Record 6 of Set 10 | oktyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 10 | port hedland
# Processing Record 8 of Set 10 | tomatlan
# Processing Record 9 of Set 10 | calbuco
# Processing Record 10 of Set 10 | sabzevar
# Processing Record 11 of Set 10 | farmington
# Processing Record 12 of Set 10 | gambela
# Processing Record 13 of Set 10 | lillooet
# Processing Record 14 of Set 10 | honiara
# Processing Record 15 of Set 10 | leh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 10 | zhigansk
# Processing Record 17 of Set 10 | antofagasta
# Processing Record 18 of Set 10 | sao filipe
# City not found. Skipping...
# Processing Record 19 of Set 10 | baijiantan
# Processing Record 20 of Set 10 | port alberni
# Processing Record 21 of Set 10 | takoradi
# Processing Record 22 of Set 10 | abha
# Processing Record 23 of Set 10 | marang
# Processing Record 24 of Set 10 | cabedelo
# Processing Record 25 of Set 10 | nishihara
# Processing Record 26 of Set 10 | tyrma
# Processing Record 27 of Set 10 | pangnirtung
# Processing Record 28 of Set 10 | otradnoye
# Processing Record 29 of Set 10 | elko
# Processing Record 30 of Set 10 | jistebnice
# Processing Record 31 of Set 10 | bambanglipuro
# Processing Record 32 of Set 10 | socorro
# Processing Record 33 of Set 10 | noshiro
# Processing Record 34 of Set 10 | aldama
# Processing Record 35 of Set 10 | kazachinskoye
# Processing Record 36 of Set 10 | mahanje
# Processing Record 37 of Set 10 | teya
# Processing Record 38 of Set 10 | lensk
# Processing Record 39 of Set 10 | vila franca do campo
# Processing Record 40 of Set 10 | caucaia
# Processing Record 41 of Set 10 | dalhousie
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 10 | sorland
# Processing Record 43 of Set 10 | havelock
# Processing Record 44 of Set 10 | puerto del rosario
# Processing Record 45 of Set 10 | veselynove
# Processing Record 46 of Set 10 | bud
# Processing Record 47 of Set 10 | amapa
# Processing Record 48 of Set 10 | sur
# Processing Record 49 of Set 10 | turayf
# Processing Record 1 of Set 11 | ballina
# City not found. Skipping...
# Processing Record 2 of Set 11 | mae hong son
# Processing Record 3 of Set 11 | bull savanna
# Processing Record 4 of Set 11 | filadelfia
# Processing Record 5 of Set 11 | chudovo
# Processing Record 6 of Set 11 | agua verde
# Processing Record 7 of Set 11 | mansa
# Processing Record 8 of Set 11 | kamenka
# Processing Record 9 of Set 11 | chukhloma
# Processing Record 10 of Set 11 | cacheu
# Processing Record 11 of Set 11 | vila do maio
# Processing Record 12 of Set 11 | pirajui
# Processing Record 13 of Set 11 | storebo
# City not found. Skipping...
# Processing Record 14 of Set 11 | kathmandu
# City not found. Skipping...
# Processing Record 15 of Set 11 | minab
# Processing Record 16 of Set 11 | alice springs
# Processing Record 17 of Set 11 | keti bandar
# Processing Record 18 of Set 11 | glenwood springs
# Processing Record 19 of Set 11 | luangwa
# Processing Record 20 of Set 11 | saint-francois
# Processing Record 21 of Set 11 | mana
# Processing Record 22 of Set 11 | carbonia
# Processing Record 23 of Set 11 | banjar
# Processing Record 24 of Set 11 | amalapuram
# Processing Record 25 of Set 11 | bathsheba
# City not found. Skipping...
# Processing Record 26 of Set 11 | belyy yar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 11 | longavi
# Processing Record 28 of Set 11 | college
# City not found. Skipping...
# Processing Record 29 of Set 11 | pombas
# Processing Record 30 of Set 11 | ankola
# Processing Record 31 of Set 11 | loa janan
# Processing Record 32 of Set 11 | kamaishi
# Processing Record 33 of Set 11 | barbosa ferraz
# Processing Record 34 of Set 11 | bantry
# Processing Record 35 of Set 11 | chicama
# Processing Record 36 of Set 11 | lasa
# Processing Record 37 of Set 11 | touho
# Processing Record 38 of Set 11 | miandoab
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 11 | haines junction
# Processing Record 40 of Set 11 | mezen
# Processing Record 41 of Set 11 | west plains
# Processing Record 42 of Set 11 | ninghai
# Processing Record 43 of Set 11 | lamu
# Processing Record 44 of Set 11 | lufilufi
# Processing Record 45 of Set 11 | severo-kurilsk
# Processing Record 46 of Set 11 | san jose
# Processing Record 47 of Set 11 | belmonte
# Processing Record 48 of Set 11 | nantucket
# City not found. Skipping...
# Processing Record 49 of Set 11 | huancayo
# Processing Record 1 of Set 12 | surt
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 12 | handan
# City not found. Skipping...
# Processing Record 3 of Set 12 | kalmar
# Processing Record 4 of Set 12 | kupang
# Processing Record 5 of Set 12 | dauriya
# Processing Record 6 of Set 12 | sydney
# Processing Record 7 of Set 12 | areosa
# Processing Record 8 of Set 12 | waddan
# Processing Record 9 of Set 12 | nuuk
# Processing Record 10 of Set 12 | port saint lucie
# Processing Record 11 of Set 12 | weifang
# Processing Record 12 of Set 12 | lumeje
# Processing Record 13 of Set 12 | tokur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}


    
# establish dataframe
weather_dataframe = pd.DataFrame(weather_dict)
# show the top of the dataframe
weather_dataframe.head()
# Out:
#        City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0     pussi         100      EE  1670384620        94  59.3600   27.0497
# 1   waipawa          57      NZ  1670384620        55 -41.4122  175.5153
# 2  tampakan          63      PH  1670384620        57   6.4442  124.9264
# 3   aklavik         100      CA  1670384621        88  68.2191 -135.0107
# 4  thompson          20      CA  1670384615        69  55.7435  -97.8558
#
#    Max Temp  Wind Speed
# 0     27.45       10.94
# 1     55.08       12.41
# 2     88.09        2.33
# 3     -6.25       11.86
# 4    -20.04        9.22

# %%
# Export the City_Data into a csv
weather_dataframe.to_csv("../output_data/cities.csv", index_label="City_ID")
weather_dataframe = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
weather_dataframe.head()
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# City_ID
# 0           pussi         100      EE  1670384620        94  59.3600
# 1         waipawa          57      NZ  1670384620        55 -41.4122
# 2        tampakan          63      PH  1670384620        57   6.4442
# 3         aklavik         100      CA  1670384621        88  68.2191
# 4        thompson          20      CA  1670384615        69  55.7435
#
#               Lng  Max Temp  Wind Speed
# City_ID
# 0         27.0497     27.45       10.94
# 1        175.5153     55.08       12.41
# 2        124.9264     88.09        2.33
# 3       -135.0107     -6.25       11.86
# 4        -97.8558    -20.04        9.22

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Temperature (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Humidity (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
weather_data_north = weather_dataframe[weather_dataframe['Lat'] >= 0]

weather_data_south = weather_dataframe[weather_dataframe['Lat'] < 0]

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temperature (F)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(1, 1), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(min(weather_dataframe['Max Temp'])-10, max(weather_dataframe['Max Temp'])+10)

# Set the limits of the x axis:
plt.xlim(-3, max(weather_dataframe['Lat'])+3)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. MaxTemp_North.png')

# Show plot:
plt.show()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq2 = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temp', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq2,(-25,43),fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(30, 100)

# Set the limits of the x axis:
plt.xlim(min(weather_dataframe['Lat'])-3, +1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. MaxTemp_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude', fontsize=20)
plt.ylabel('Humidity (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(51,6),fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-6, 110)

# Set the limits of the x axis:
plt.xlim(-4, 82)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Humidity_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude', fontsize=20)
plt.ylabel('Humidity (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-55,22), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(10, 110)

# Set the limits of the x axis:
plt.xlim(-57, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Humidity_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(35,25), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-8, 110)

# Set the limits of the x axis:
plt.xlim(-3, 82)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Cloudiness_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-56,8), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-7, 108)

# Set the limits of the x axis:
plt.xlim(-58, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Cloudiness_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Wind Speed']

# Perform a linear regression for wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed (mph)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(2,42), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-3, 48)

# Set the limits of the x axis:
plt.xlim(-3, 82)


# Save the figure:
plt.savefig('../output_data/City Latitude vs. Wind_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Wind Speed']

# Perform a linear regression on wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed (mph)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-19.5,21), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-1, 25)

# Set the limits of the x axis:
plt.xlim(-58, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Wind_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
