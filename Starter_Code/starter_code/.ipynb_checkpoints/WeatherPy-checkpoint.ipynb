# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
temp_units = "imperial"
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output CSV
output_data_file = "Output/weather_df.csv"

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []
# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 585

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | mazatlan
# Processing Record 5 of Set 1 | redmond
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | aksarka
# City not found. Skipping...
# Processing Record 8 of Set 1 | robertsport
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | sarangani
# Processing Record 11 of Set 1 | werda
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | baykit
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | olafsvik
# Processing Record 20 of Set 1 | qaanaaq
# City not found. Skipping...
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | bhuban
# City not found. Skipping...
# Processing Record 23 of Set 1 | warrington
# Processing Record 24 of Set 1 | narsaq
# City not found. Skipping...
# Processing Record 25 of Set 1 | dali
# Processing Record 26 of Set 1 | grand river south east
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 29 of Set 1 | marystown
# Processing Record 30 of Set 1 | afua
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | san miguel el alto
# Processing Record 35 of Set 1 | heihe
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | portland
# Processing Record 40 of Set 1 | aguimes
# Processing Record 41 of Set 1 | prince george
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | huarmey
# Processing Record 44 of Set 1 | canico
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | gat
# City not found. Skipping...
# Processing Record 47 of Set 1 | tabou
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | tadine
# Processing Record 1 of Set 2 | esperance
# City not found. Skipping...
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | inuvik
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | pierre
# Processing Record 7 of Set 2 | hegra
# Processing Record 8 of Set 2 | samarai
# Processing Record 9 of Set 2 | poum
# Processing Record 10 of Set 2 | chernivtsi
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | daru
# City not found. Skipping...
# Processing Record 13 of Set 2 | pontianak
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | leningradskiy
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | port moresby
# Processing Record 20 of Set 2 | krasnoselkup
# Processing Record 21 of Set 2 | maryville
# Processing Record 22 of Set 2 | havre-saint-pierre
# Processing Record 23 of Set 2 | sorsk
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | berlevag
# Processing Record 27 of Set 2 | grand baie
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | catamarca
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | biltine
# Processing Record 35 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 36 of Set 2 | sur
# Processing Record 37 of Set 2 | taltal
# Processing Record 38 of Set 2 | mys shmidta
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | adrar
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | porto walter
# Processing Record 44 of Set 2 | pacific grove
# Processing Record 45 of Set 2 | sitka
# Processing Record 46 of Set 2 | carnarvon
# City not found. Skipping...
# Processing Record 47 of Set 2 | moussoro
# Processing Record 48 of Set 2 | rocha
# Processing Record 49 of Set 2 | kavieng
# City not found. Skipping...
# Processing Record 1 of Set 3 | fraserburgh
# Processing Record 2 of Set 3 | talnakh
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | yar-sale
# Processing Record 5 of Set 3 | balkanabat
# Processing Record 6 of Set 3 | lagoa
# Processing Record 7 of Set 3 | zhezkazgan
# Processing Record 8 of Set 3 | ancud
# Processing Record 9 of Set 3 | jalu
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | kem
# Processing Record 12 of Set 3 | tonekabon
# City not found. Skipping...
# Processing Record 13 of Set 3 | casa grande
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | wadsworth
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | chaman
# Processing Record 18 of Set 3 | deputatskiy
# Processing Record 19 of Set 3 | nemuro
# Processing Record 20 of Set 3 | nantucket
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | raudeberg
# City not found. Skipping...
# Processing Record 23 of Set 3 | souillac
# Processing Record 24 of Set 3 | sibolga
# Processing Record 25 of Set 3 | port hardy
# Processing Record 26 of Set 3 | khatanga
# Processing Record 27 of Set 3 | tir pol
# Processing Record 28 of Set 3 | isakly
# Processing Record 29 of Set 3 | san cristobal
# City not found. Skipping...
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | bondo
# Processing Record 32 of Set 3 | teguldet
# City not found. Skipping...
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | green valley
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | acapulco
# Processing Record 37 of Set 3 | torbay
# Processing Record 38 of Set 3 | parsons
# City not found. Skipping...
# Processing Record 39 of Set 3 | cam ranh
# Processing Record 40 of Set 3 | fort walton beach
# City not found. Skipping...
# Processing Record 41 of Set 3 | maniitsoq
# Processing Record 42 of Set 3 | cabo san lucas
# City not found. Skipping...
# Processing Record 43 of Set 3 | norden
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | upernavik
# Processing Record 46 of Set 3 | creston
# City not found. Skipping...
# Processing Record 47 of Set 3 | mykolayiv
# Processing Record 48 of Set 3 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 49 of Set 3 | srednekolymsk
# Processing Record 1 of Set 4 | tateyama
# Processing Record 2 of Set 4 | freeport
# Processing Record 3 of Set 4 | chengde
# Processing Record 4 of Set 4 | kaffrine
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | ofunato
# Processing Record 7 of Set 4 | zhangye
# Processing Record 8 of Set 4 | lorengau
# Processing Record 9 of Set 4 | fairbanks
# Processing Record 10 of Set 4 | bida
# Processing Record 11 of Set 4 | flinders
# Processing Record 12 of Set 4 | coquimbo
# Processing Record 13 of Set 4 | kruisfontein
# Processing Record 14 of Set 4 | sabha
# Processing Record 15 of Set 4 | vanimo
# Processing Record 16 of Set 4 | sirpur
# Processing Record 17 of Set 4 | vanderhoof
# Processing Record 18 of Set 4 | soubre
# Processing Record 19 of Set 4 | pevek
# City not found. Skipping...
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | maunabo
# Processing Record 22 of Set 4 | ormara
# Processing Record 23 of Set 4 | inongo
# Processing Record 24 of Set 4 | glendive
# Processing Record 25 of Set 4 | san quintin
# City not found. Skipping...
# Processing Record 26 of Set 4 | kirakira
# Processing Record 27 of Set 4 | alnavar
# Processing Record 28 of Set 4 | wajima
# Processing Record 29 of Set 4 | saskylakh
# Processing Record 30 of Set 4 | weleri
# Processing Record 31 of Set 4 | byron bay
# Processing Record 32 of Set 4 | dartford
# Processing Record 33 of Set 4 | roald
# Processing Record 34 of Set 4 | mansa
# Processing Record 35 of Set 4 | monrovia
# Processing Record 36 of Set 4 | bereda
# Processing Record 37 of Set 4 | bowen
# Processing Record 38 of Set 4 | plotnikovo
# Processing Record 39 of Set 4 | perbaungan
# Processing Record 40 of Set 4 | mount pleasant
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | juneau
# Processing Record 43 of Set 4 | kahului
# City not found. Skipping...
# Processing Record 44 of Set 4 | pathein
# Processing Record 45 of Set 4 | cabo rojo
# Processing Record 46 of Set 4 | bako
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | manokwari
# Processing Record 49 of Set 4 | pundaguitan
# Processing Record 1 of Set 5 | puri
# Processing Record 2 of Set 5 | katsuura
# Processing Record 3 of Set 5 | leh
# Processing Record 4 of Set 5 | bogorodskoye
# Processing Record 5 of Set 5 | taoudenni
# Processing Record 6 of Set 5 | tual
# City not found. Skipping...
# Processing Record 7 of Set 5 | ulladulla
# Processing Record 8 of Set 5 | meulaboh
# Processing Record 9 of Set 5 | laguna
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | hithadhoo
# Processing Record 12 of Set 5 | sambava
# Processing Record 13 of Set 5 | araouane
# Processing Record 14 of Set 5 | chapais
# Processing Record 15 of Set 5 | sisimiut
# Processing Record 16 of Set 5 | inta
# Processing Record 17 of Set 5 | wewak
# Processing Record 18 of Set 5 | eluru
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | teguise
# Processing Record 21 of Set 5 | korla
# City not found. Skipping...
# Processing Record 22 of Set 5 | longyearbyen
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | naze
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | hovd
# Processing Record 27 of Set 5 | beberibe
# Processing Record 28 of Set 5 | honiara
# Processing Record 29 of Set 5 | tautira
# Processing Record 30 of Set 5 | kieta
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | cassilandia
# Processing Record 33 of Set 5 | carutapera
# Processing Record 34 of Set 5 | coroneo
# Processing Record 35 of Set 5 | hamilton
# Processing Record 36 of Set 5 | kajaani
# City not found. Skipping...
# Processing Record 37 of Set 5 | szprotawa
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 5 | prince rupert
# City not found. Skipping...
# Processing Record 39 of Set 5 | esqueda
# Processing Record 40 of Set 5 | banda aceh
# Processing Record 41 of Set 5 | chara
# Processing Record 42 of Set 5 | hanna
# Processing Record 43 of Set 5 | moron
# Processing Record 44 of Set 5 | imeni poliny osipenko
# Processing Record 45 of Set 5 | avera
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | mana
# Processing Record 48 of Set 5 | busayra
# Processing Record 49 of Set 5 | isangel
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | khilok
# Processing Record 3 of Set 6 | east london
# Processing Record 4 of Set 6 | westport
# Processing Record 5 of Set 6 | tupik
# Processing Record 6 of Set 6 | ponta delgada
# Processing Record 7 of Set 6 | laredo
# Processing Record 8 of Set 6 | ardee
# Processing Record 9 of Set 6 | atambua
# Processing Record 10 of Set 6 | clyde river
# City not found. Skipping...
# Processing Record 11 of Set 6 | aras
# Processing Record 12 of Set 6 | porto santo
# Processing Record 13 of Set 6 | ribeira grande
# Processing Record 14 of Set 6 | gornozavodsk
# Processing Record 15 of Set 6 | athabasca
# Processing Record 16 of Set 6 | volkhovskiy
# Processing Record 17 of Set 6 | sohag
# Processing Record 18 of Set 6 | coahuayana
# Processing Record 19 of Set 6 | salalah
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 6 | nurota
# Processing Record 21 of Set 6 | ondarroa
# Processing Record 22 of Set 6 | svetlogorsk
# Processing Record 23 of Set 6 | seoul
# City not found. Skipping...
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | dingle
# Processing Record 26 of Set 6 | moose factory
# Processing Record 27 of Set 6 | strezhevoy
# Processing Record 28 of Set 6 | ucluelet
# Processing Record 29 of Set 6 | caravelas
# Processing Record 30 of Set 6 | dagana
# City not found. Skipping...
# Processing Record 31 of Set 6 | mizdah
# Processing Record 32 of Set 6 | linhares
# Processing Record 33 of Set 6 | guerrero negro
# Processing Record 34 of Set 6 | takoradi
# Processing Record 35 of Set 6 | hami
# City not found. Skipping...
# Processing Record 36 of Set 6 | fortuna
# Processing Record 37 of Set 6 | asau
# Processing Record 38 of Set 6 | nelidovo
# Processing Record 39 of Set 6 | verkhnyaya inta
# City not found. Skipping...
# Processing Record 40 of Set 6 | horodnye
# Processing Record 41 of Set 6 | merauke
# Processing Record 42 of Set 6 | nosy varika
# Processing Record 43 of Set 6 | kinkala
# Processing Record 44 of Set 6 | verkh-usugli
# Processing Record 45 of Set 6 | tarko-sale
# Processing Record 46 of Set 6 | shimoda
# Processing Record 47 of Set 6 | kalach-na-donu
# Processing Record 48 of Set 6 | faya
# Processing Record 49 of Set 6 | senekal
# Processing Record 1 of Set 7 | axim
# Processing Record 2 of Set 7 | sicuani
# Processing Record 3 of Set 7 | anadyr
# Processing Record 4 of Set 7 | qostanay
# City not found. Skipping...
# Processing Record 5 of Set 7 | grindavik
# Processing Record 6 of Set 7 | tezu
# Processing Record 7 of Set 7 | zatoka
# City not found. Skipping...
# Processing Record 8 of Set 7 | davila
# Processing Record 9 of Set 7 | ternate
# Processing Record 10 of Set 7 | erie
# Processing Record 11 of Set 7 | manaure
# Processing Record 12 of Set 7 | perth
# Processing Record 13 of Set 7 | sindor
# Processing Record 14 of Set 7 | buala
# Processing Record 15 of Set 7 | hualmay
# Processing Record 16 of Set 7 | san policarpo
# Processing Record 17 of Set 7 | porto belo
# Processing Record 18 of Set 7 | lavrentiya
# City not found. Skipping...
# Processing Record 19 of Set 7 | eidfjord
# Processing Record 20 of Set 7 | tuatapere
# Processing Record 21 of Set 7 | suihua
# Processing Record 22 of Set 7 | pierrelatte
# Processing Record 23 of Set 7 | sokoni
# Processing Record 24 of Set 7 | buchanan
# City not found. Skipping...
# Processing Record 25 of Set 7 | vila velha
# Processing Record 26 of Set 7 | maxixe
# Processing Record 27 of Set 7 | broome
# Processing Record 28 of Set 7 | biak
# Processing Record 29 of Set 7 | gamboma
# Processing Record 30 of Set 7 | bathsheba
# Processing Record 31 of Set 7 | humboldt
# Processing Record 32 of Set 7 | tecoanapa
# Processing Record 33 of Set 7 | shingu
# Processing Record 34 of Set 7 | kijang
# Processing Record 35 of Set 7 | cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 7 | qandala
# Processing Record 37 of Set 7 | vanavara
# Processing Record 38 of Set 7 | petrove
# Processing Record 39 of Set 7 | ahtopol
# Processing Record 40 of Set 7 | noumea
# Processing Record 41 of Set 7 | artsyz
# Processing Record 42 of Set 7 | elizabeth city
# Processing Record 43 of Set 7 | zapolyarnyy
# Processing Record 44 of Set 7 | smithers
# Processing Record 45 of Set 7 | port lincoln
# Processing Record 46 of Set 7 | kalmunai
# Processing Record 47 of Set 7 | valdivia
# Processing Record 48 of Set 7 | eregli
# Processing Record 49 of Set 7 | mayo
# Processing Record 1 of Set 8 | rawson
# Processing Record 2 of Set 8 | fosforitnyy
# Processing Record 3 of Set 8 | aklavik
# Processing Record 4 of Set 8 | bilma
# Processing Record 5 of Set 8 | hutang
# Processing Record 6 of Set 8 | koryukivka
# Processing Record 7 of Set 8 | cabedelo
# City not found. Skipping...
# Processing Record 8 of Set 8 | linping
# Processing Record 9 of Set 8 | gravdal
# Processing Record 10 of Set 8 | kilrush
# Processing Record 11 of Set 8 | raymondville
# Processing Record 12 of Set 8 | camocim
# Processing Record 13 of Set 8 | roura
# Processing Record 14 of Set 8 | sawtell
# Processing Record 15 of Set 8 | natchez
# Processing Record 16 of Set 8 | sederot
# Processing Record 17 of Set 8 | nalut
# Processing Record 18 of Set 8 | goderich
# Processing Record 19 of Set 8 | haines junction
# City not found. Skipping...
# Processing Record 20 of Set 8 | samfya
# Processing Record 21 of Set 8 | labrea
# Processing Record 22 of Set 8 | padang
# Processing Record 23 of Set 8 | cap malheureux
# Processing Record 24 of Set 8 | klaksvik
# Processing Record 25 of Set 8 | pemangkat
# Processing Record 26 of Set 8 | vestmannaeyjar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 8 | hokitika
# Processing Record 28 of Set 8 | victor harbor
# Processing Record 29 of Set 8 | visakhapatnam
# City not found. Skipping...
# Processing Record 30 of Set 8 | labuhan
# Processing Record 31 of Set 8 | komsomolskiy
# City not found. Skipping...
# Processing Record 32 of Set 8 | tiarei
# Processing Record 33 of Set 8 | altus
# Processing Record 34 of Set 8 | dezhou
# Processing Record 35 of Set 8 | borba
# Processing Record 36 of Set 8 | launceston
# Processing Record 37 of Set 8 | ngunguru
# Processing Record 38 of Set 8 | raahe
# Processing Record 39 of Set 8 | terre-de-bas
# Processing Record 40 of Set 8 | kharela
# City not found. Skipping...
# Processing Record 41 of Set 8 | ukiah
# Processing Record 42 of Set 8 | saint-pierre
# Processing Record 43 of Set 8 | kemin
# Processing Record 44 of Set 8 | hohhot
# Processing Record 45 of Set 8 | priargunsk
# Processing Record 46 of Set 8 | strathmore
# Processing Record 47 of Set 8 | amuntai
# Processing Record 48 of Set 8 | awbari
# Processing Record 49 of Set 8 | asekeyevo
# Processing Record 1 of Set 9 | san mateo del mar
# Processing Record 2 of Set 9 | fasa
# Processing Record 3 of Set 9 | whitehorse
# Processing Record 4 of Set 9 | port blair
# City not found. Skipping...
# Processing Record 5 of Set 9 | myre
# Processing Record 6 of Set 9 | sola
# Processing Record 7 of Set 9 | kloulklubed
# Processing Record 8 of Set 9 | dalvik
# Processing Record 9 of Set 9 | uribia
# Processing Record 10 of Set 9 | fukuma
# Processing Record 11 of Set 9 | rio hondo
# Processing Record 12 of Set 9 | ola
# Processing Record 13 of Set 9 | minab
# Processing Record 14 of Set 9 | baruun-urt
# Processing Record 15 of Set 9 | saint-augustin
# Processing Record 16 of Set 9 | yamada
# Processing Record 17 of Set 9 | ures
# Processing Record 18 of Set 9 | kushima
# Processing Record 19 of Set 9 | namatanai
# Processing Record 20 of Set 9 | tazovskiy
# Processing Record 21 of Set 9 | balikpapan
# Processing Record 22 of Set 9 | veraval
# Processing Record 23 of Set 9 | panshi
# Processing Record 24 of Set 9 | presidente medici
# City not found. Skipping...
# Processing Record 25 of Set 9 | tilichiki
# Processing Record 26 of Set 9 | singleton
# Processing Record 27 of Set 9 | nouadhibou
# Processing Record 28 of Set 9 | saint-georges
# Processing Record 29 of Set 9 | inverell
# Processing Record 30 of Set 9 | sobolevo
# Processing Record 31 of Set 9 | vardo
# Processing Record 32 of Set 9 | dustlik
# Processing Record 33 of Set 9 | guia de isora
# Processing Record 34 of Set 9 | yarim
# Processing Record 35 of Set 9 | basti
# Processing Record 36 of Set 9 | codrington
# Processing Record 37 of Set 9 | lagos
# Processing Record 38 of Set 9 | aripuana
# City not found. Skipping...
# Processing Record 39 of Set 9 | greenfield
# Processing Record 40 of Set 9 | langham
# Processing Record 41 of Set 9 | muswellbrook
# Processing Record 42 of Set 9 | hereford
# Processing Record 43 of Set 9 | palauig
# Processing Record 44 of Set 9 | waitati
# Processing Record 45 of Set 9 | kununurra
# Processing Record 46 of Set 9 | vostok
# City not found. Skipping...
# Processing Record 47 of Set 9 | shenjiamen
# City not found. Skipping...
# Processing Record 48 of Set 9 | niigata
# Processing Record 49 of Set 9 | san ignacio
# Processing Record 1 of Set 10 | mugumu
# Processing Record 2 of Set 10 | acajutla
# Processing Record 3 of Set 10 | chihuahua
# Processing Record 4 of Set 10 | gao
# Processing Record 5 of Set 10 | yoichi
# Processing Record 6 of Set 10 | totness
# Processing Record 7 of Set 10 | yaan
# Processing Record 8 of Set 10 | tukrah
# Processing Record 9 of Set 10 | carson city
# Processing Record 10 of Set 10 | polunochnoye
# Processing Record 11 of Set 10 | markova
# Processing Record 12 of Set 10 | timmins
# Processing Record 13 of Set 10 | palmares
# Processing Record 14 of Set 10 | port hedland
# City not found. Skipping...
# Processing Record 15 of Set 10 | port macquarie
# City not found. Skipping...
# Processing Record 16 of Set 10 | cayenne
# Processing Record 17 of Set 10 | tsybli
# Processing Record 18 of Set 10 | reftinskiy
# Processing Record 19 of Set 10 | jaypur
# Processing Record 20 of Set 10 | seymchan
# Processing Record 21 of Set 10 | maniwaki
# Processing Record 22 of Set 10 | lagunas
# Processing Record 23 of Set 10 | ekhabi
# Processing Record 24 of Set 10 | mirnyy
# Processing Record 25 of Set 10 | novyy urengoy
# Processing Record 26 of Set 10 | lewiston
# Processing Record 27 of Set 10 | irituia
# Processing Record 28 of Set 10 | luwuk
# Processing Record 29 of Set 10 | san patricio
# Processing Record 30 of Set 10 | brae
# Processing Record 31 of Set 10 | cacu
# Processing Record 32 of Set 10 | slidell
# Processing Record 33 of Set 10 | narasannapeta
# Processing Record 34 of Set 10 | acarau
# Processing Record 35 of Set 10 | iquitos
# Processing Record 36 of Set 10 | namibe
# Processing Record 37 of Set 10 | ballina
# City not found. Skipping...
# Processing Record 38 of Set 10 | manzhouli
# Processing Record 39 of Set 10 | kerema
# Processing Record 40 of Set 10 | lazaro cardenas
# Processing Record 41 of Set 10 | barda
# Processing Record 42 of Set 10 | kumo
# Processing Record 43 of Set 10 | bull savanna
# Processing Record 44 of Set 10 | boddam
# Processing Record 45 of Set 10 | zanjan
# City not found. Skipping...
# Processing Record 46 of Set 10 | poopo
# Processing Record 47 of Set 10 | normandin
# Processing Record 48 of Set 10 | nikolsk
# Processing Record 49 of Set 10 | lulea
# Processing Record 1 of Set 11 | newport
# City not found. Skipping...
# Processing Record 2 of Set 11 | hailar
# Processing Record 3 of Set 11 | bubaque
# Processing Record 4 of Set 11 | areosa
# Processing Record 5 of Set 11 | suntar
# Processing Record 6 of Set 11 | ambilobe
# Processing Record 7 of Set 11 | aswan
# Processing Record 8 of Set 11 | lao cai
# Processing Record 9 of Set 11 | vila franca do campo
# Processing Record 10 of Set 11 | guaruja
# Processing Record 11 of Set 11 | sao miguel do oeste
# Processing Record 12 of Set 11 | progreso
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 11 | ouango
# Processing Record 14 of Set 11 | malanje
# Processing Record 15 of Set 11 | jumla
# Processing Record 16 of Set 11 | methoni
# City not found. Skipping...
# Processing Record 17 of Set 11 | pacifica
# City not found. Skipping...
# Processing Record 18 of Set 11 | wolgast
# Processing Record 19 of Set 11 | sompeta
# Processing Record 20 of Set 11 | sankheda
# Processing Record 21 of Set 11 | hambantota
# Processing Record 22 of Set 11 | san jose
# Processing Record 23 of Set 11 | scarborough
# Processing Record 24 of Set 11 | rosetta
# Processing Record 25 of Set 11 | halifax
# Processing Record 26 of Set 11 | bara
# City not found. Skipping...
# Processing Record 27 of Set 11 | vagur
# Processing Record 28 of Set 11 | vao
# Processing Record 29 of Set 11 | gora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}


    
# establish dataframe
city_data_df  = pd.DataFrame(weather_dict)
# show the top of the dataframe
city_data_df .head()
# Out:
#           City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0  tuktoyaktuk          99      CA  1670385689        82  69.4541 -133.0374
# 1       barrow         100      US  1670385477        91  71.2906 -156.7887
# 2    busselton           1      AU  1670385690        33 -33.6500  115.3333
# 3     mazatlan          20      MX  1670385676        96  23.2167 -106.4167
# 4      redmond         100      US  1670385643        93  47.6740 -122.1215
#
#    Max Temp  Wind Speed
# 0    -14.93       10.40
# 1      8.73       17.98
# 2     75.42        1.63
# 3     75.02        1.99
# 4     43.90        1.99

# %%
# Export the City_Data into a csv
city_data_df .to_csv("../output_data/cities.csv", index_label="City_ID")
city_data_df  = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df .head()
# Out:
#                 City  Cloudiness Country        Date  Humidity      Lat  \
# City_ID
# 0        tuktoyaktuk          99      CA  1670385689        82  69.4541
# 1             barrow         100      US  1670385477        91  71.2906
# 2          busselton           1      AU  1670385690        33 -33.6500
# 3           mazatlan          20      MX  1670385676        96  23.2167
# 4            redmond         100      US  1670385643        93  47.6740
#
#               Lng  Max Temp  Wind Speed
# City_ID
# 0       -133.0374    -14.93       10.40
# 1       -156.7887      8.73       17.98
# 2        115.3333     75.42        1.63
# 3       -106.4167     75.02        1.99
# 4       -122.1215     43.90        1.99

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df ["Lat"],city_data_df ["Max Temp"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Temperature (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df ["Lat"],city_data_df ["Humidity"],edgecolors="black",facecolors="blue")
plt.title("City Latitude vs. Humidity (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df ["Lat"],city_data_df ["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df ["Lat"],city_data_df ["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (2022/10/18)")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
weather_data_north = city_data_df [city_data_df ['Lat'] >= 0]

weather_data_south = city_data_df [city_data_df ['Lat'] < 0]

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temperature (F)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(1, 1), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(min(city_data_df['Max Temp'])-10, max(city_data_df['Max Temp'])+10)

# Set the limits of the x axis:
plt.xlim(-3, max(city_data_df['Lat'])+3)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. MaxTemp_North.png')

# Show plot:
plt.show()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq2 = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temp', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq2,(-25,43),fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(30, 100)

# Set the limits of the x axis:
plt.xlim(min(city_data_df['Lat'])-3, +1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. MaxTemp_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude', fontsize=20)
plt.ylabel('Humidity (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(51,6),fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-6, 110)

# Set the limits of the x axis:
plt.xlim(-4, 82)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Humidity_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude', fontsize=20)
plt.ylabel('Humidity (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-55,22), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(10, 110)

# Set the limits of the x axis:
plt.xlim(-57, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Humidity_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(35,25), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-8, 110)

# Set the limits of the x axis:
plt.xlim(-3, 82)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Cloudiness_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness (%)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-56,8), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-7, 108)

# Set the limits of the x axis:
plt.xlim(-58, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Cloudiness_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Wind Speed']

# Perform a linear regression for wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed (mph)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(2,42), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-3, 48)

# Set the limits of the x axis:
plt.xlim(-3, 82)


# Save the figure:
plt.savefig('../output_data/City Latitude vs. Wind_North.png')

# Show plot:
plt.show()

# %%
# Southern Hemisphere
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Wind Speed']

# Perform a linear regression on wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='royalblue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'darkred', linewidth=2)

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed (mph)', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-19.5,21), fontsize=18, color='darkred')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-1, 25)

# Set the limits of the x axis:
plt.xlim(-58, 1)

# Save the figure:
plt.savefig('../output_data/City Latitude vs. Wind_South.png')

# Show plot:
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
